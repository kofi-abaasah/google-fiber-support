# %% [markdown]
# **Import Packages**

# %%
import os 
import pandas as pd 
import numpy as np 
import dataframe_image as dfi 
import pickle

# %%
path1 = 'https://drive.google.com/uc?id=1k5bjKmxONx78sdXkjDfaYjvFBV4Elh7a'
path2 = 'https://drive.google.com/uc?id=1yzLHtrUjWsv7BYIcHnvLLcv3EK_IRSQq'
path3 = 'https://drive.google.com/uc?id=1CTegUqpAf_qmhMZGMh4nUlYk-4iIIkuO'

current_directory = os.getcwd()

data1 = pd.read_csv(path1)
data2 = pd.read_csv(path2)
data3 = pd.read_csv(path3)

# %% [markdown]
# **Explore The Data**

# %%
data1.head()
# Out:
#   date_created  contacts_n  contacts_n_1  contacts_n_2  contacts_n_3  \
# 0   2022-02-04      199.00         21.00          6.00         11.00
# 1   2022-01-30       19.00          2.00          0.00          2.00
# 2   2022-02-14       29.00          0.00          2.00          2.00
# 3   2022-01-16      120.00          6.00          6.00          5.00
# 4   2022-02-03      182.00         27.00         13.00           NaN
#
#    contacts_n_4  contacts_n_5  contacts_n_6  contacts_n_7 new_type new_market
# 0          7.00         14.00          5.00          6.00   type_5   market_1
# 1          1.00          0.00          0.00          0.00   type_1   market_1
# 2          0.00          1.00          0.00          1.00   type_1   market_1
# 3          4.00          7.00          4.00           NaN   type_2   market_1
# 4         14.00          4.00          3.00          2.00   type_5   market_1

# %%
data2.head()
# Out:
#   date_created  contacts_n  contacts_n_1  contacts_n_2  contacts_n_3  \
# 0   2022-03-16         NaN           NaN           NaN           NaN
# 1   2022-02-01       28.00          1.00           NaN          1.00
# 2   2022-01-05       11.00          2.00          0.00          0.00
# 3   2022-03-30       38.00          3.00          2.00           NaN
# 4   2022-01-24        1.00          0.00          0.00          0.00
#
#    contacts_n_4  contacts_n_5  contacts_n_6  contacts_n_7 new_type new_market
# 0           NaN          1.00           NaN           NaN   type_4   market_2
# 1           NaN           NaN          2.00           NaN   type_2   market_2
# 2          0.00          0.00          0.00          0.00   type_1   market_2
# 3           NaN           NaN           NaN          1.00   type_5   market_2
# 4          0.00          0.00          0.00          0.00   type_1   market_2

# %%
data3.head()
# Out:
#   date_created  contacts_n  contacts_n_1  contacts_n_2  contacts_n_3  \
# 0   2022-02-17        9.00          3.00          1.00           NaN
# 1   2022-01-04        8.00          3.00          3.00           NaN
# 2   2022-03-16       27.00          3.00          2.00          2.00
# 3   2022-01-23        9.00           NaN           NaN           NaN
# 4   2022-02-06        2.00           NaN           NaN           NaN
#
#    contacts_n_4  contacts_n_5  contacts_n_6  contacts_n_7 new_type new_market
# 0          2.00          2.00           NaN          2.00   type_3   market_3
# 1           NaN           NaN           NaN          1.00   type_3   market_3
# 2           NaN           NaN           NaN          1.00   type_2   market_3
# 3           NaN           NaN          1.00          1.00   type_2   market_3
# 4           NaN           NaN           NaN           NaN   type_4   market_3

# %%
data1.info()
pd.set_option('display.float_format', '{:,.2f}'.format)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_created  450 non-null    object
#  1   contacts_n    440 non-null    float64
#  2   contacts_n_1  359 non-null    float64
#  3   contacts_n_2  350 non-null    float64
#  4   contacts_n_3  343 non-null    float64
#  5   contacts_n_4  330 non-null    float64
#  6   contacts_n_5  322 non-null    float64
#  7   contacts_n_6  322 non-null    float64
#  8   contacts_n_7  324 non-null    float64
#  9   new_type      450 non-null    object
#  10  new_market    450 non-null    object
# dtypes: float64(8), object(3)
# memory usage: 38.8+ KB

# %%
data1.describe()
# Out:
#        contacts_n  contacts_n_1  contacts_n_2  contacts_n_3  contacts_n_4  \
# count      440.00        359.00        350.00        343.00        330.00
# mean       103.03          9.43          6.15          4.92          4.47
# std        118.07          9.27          5.73          4.48          4.05
# min          1.00          0.00          0.00          0.00          0.00
# 25%         11.00          2.00          1.00          1.00          1.00
# 50%         28.00          6.00          4.00          3.00          3.00
# 75%        193.75         16.00         10.00          8.00          7.00
# max        599.00         46.00         27.00         21.00         19.00
#
#        contacts_n_5  contacts_n_6  contacts_n_7
# count        322.00        322.00        324.00
# mean           4.40          3.90          3.92
# std            4.16          3.61          4.07
# min            0.00          0.00          0.00
# 25%            1.00          1.00          1.00
# ...

# %% [markdown]
# **Merge Data**

# %%
data = pd.concat([data1, data2, data3]).sort_values(by="date_created", ascending=True)

# %%
data.head(10)
# Out:
#     date_created  contacts_n  contacts_n_1  contacts_n_2  contacts_n_3  \
# 219   2022-01-01         NaN           NaN           NaN           NaN
# 310   2022-01-01         NaN           NaN           NaN           NaN
# 221   2022-01-01      166.00         12.00         13.00          7.00
# 348   2022-01-01        2.00          0.00          0.00          0.00
# 427   2022-01-01        7.00           NaN           NaN           NaN
# 114   2022-01-01        2.00          0.00          1.00          0.00
# 278   2022-01-01       97.00          3.00          5.00          3.00
# 423   2022-01-01        7.00           NaN           NaN          1.00
# 449   2022-01-01       20.00          3.00          1.00           NaN
# 63    2022-01-01         NaN           NaN           NaN           NaN
#
#      contacts_n_4  contacts_n_5  contacts_n_6  contacts_n_7 new_type  \
# 219           NaN           NaN           NaN           NaN   type_4
# ...

# %% [markdown]
# **Apply Correct Formatting**

# %%
data['date_created'] = pd.to_datetime(data['date_created'])

# %%
# Check if there are any NaT values in the column
print(data['date_created'].isna().sum())  # This returns the count of NaT values
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1350 entries, 219 to 65
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_created  1350 non-null   datetime64[ns]
#  1   contacts_n    1168 non-null   float64
#  2   contacts_n_1  892 non-null    float64
#  3   contacts_n_2  821 non-null    float64
#  4   contacts_n_3  778 non-null    float64
#  5   contacts_n_4  739 non-null    float64
#  6   contacts_n_5  719 non-null    float64
#  7   contacts_n_6  716 non-null    float64
#  8   contacts_n_7  733 non-null    float64
#  9   new_type      1350 non-null   object
#  10  new_market    1350 non-null   object
# dtypes: datetime64[ns](1), float64(8), object(2)
# memory usage: 126.6+ KB

# %%
data.head()
# Out:
#     date_created  contacts_n  contacts_n_1  contacts_n_2  contacts_n_3  \
# 219   2022-01-01         NaN           NaN           NaN           NaN
# 310   2022-01-01         NaN           NaN           NaN           NaN
# 221   2022-01-01      166.00         12.00         13.00          7.00
# 348   2022-01-01        2.00          0.00          0.00          0.00
# 427   2022-01-01        7.00           NaN           NaN           NaN
#
#      contacts_n_4  contacts_n_5  contacts_n_6  contacts_n_7 new_type  \
# 219           NaN           NaN           NaN           NaN   type_4
# 310           NaN           NaN           NaN           NaN   type_3
# 221          8.00          2.00          1.00          5.00   type_5
# 348          0.00          0.00          0.00          0.00   type_1
# 427           NaN           NaN           NaN          1.00   type_3
#
#     new_market
# 219   market_1
# 310   market_2
# 221   market_1
# 348   market_2
# 427   market_1

# %%
pickle_path = os.path.join(current_directory, 'data.pkl')
data.to_pickle(pickle_path) 
print(f"Pickle file saved to: {pickle_path}")
# Out:
# Pickle file saved to: C:\Windows\System32\Google Fiber\data.pkl
